# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

# %%
# mnist is a module

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# x_train and others have numpy.ndarray type

# %%
# x_train.shape -> (60000, 28, 28 )
# y_train.shape -> (60000,)

# x_test.shape -> (10000, 28, 28)
# y_test.shape -> (10000,)

# %% [markdown]
# CIFAR 10

# %%
(x, y), (a, b) = tf.keras.datasets.cifar10.load_data()

x.shape
# Out:
# (50000, 32, 32, 3)

# %%
help(tf.keras.applications)
# Out:
# Help on package keras.api.applications in keras.api:
#
# NAME
#     keras.api.applications - DO NOT EDIT.
#
# DESCRIPTION
#     This file was autogenerated. Do not edit it by hand,
#     since your modifications would be overwritten.
#
# PACKAGE CONTENTS
#     convnext (package)
#     densenet (package)
#     efficientnet (package)
#     efficientnet_v2 (package)
#     imagenet_utils (package)
#     inception_resnet_v2 (package)
#     inception_v3 (package)
#     mobilenet (package)
#     mobilenet_v2 (package)
#     mobilenet_v3 (package)
#     nasnet (package)
#     resnet (package)
#     resnet50 (package)
#     resnet_v2 (package)
#     vgg16 (package)
#     vgg19 (package)
#     xception (package)
#
# FILE
#     c:\users\rguim\documents\dev\flower\envflwr\lib\site-packages\keras\api\applications\__init__.py

# %%
import tensorflow as tf

# Carregar o conjunto de dados MNIST
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalizar os valores de pixel para o intervalo [0, 1]
x_train, x_test = x_train / 255.0, x_test / 255.0

# Definir o modelo
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),  # Camada de entrada: achatamento da imagem
    tf.keras.layers.Dense(128, activation='relu'),  # Primeira camada oculta com 128 neurônios e função de ativação ReLU
    tf.keras.layers.Dropout(0.2),  # Regularização com dropout de 20%
    tf.keras.layers.Dense(10, activation='softmax')  # Camada de saída com 10 neurônios para as 10 classes e função de ativação softmax
])

# Compilar o modelo
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',  # Função de perda para problemas de classificação
              metrics=['accuracy'])

# Treinar o modelo
model.fit(x_train, y_train, epochs=5)

# Avaliar a precisão do modelo
test_loss, test_acc = model.evaluate(x_test, y_test)
print('\nTest accuracy:', test_acc)
# Out:
# c:\Users\rguim\Documents\DEV\FLOWER\envflwr\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8608 - loss: 0.4799
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9562 - loss: 0.1492
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9668 - loss: 0.1083
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9731 - loss: 0.0863
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9769 - loss: 0.0736
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9715 - loss: 0.0885
#
# Test accuracy: 0.9768000245094299
